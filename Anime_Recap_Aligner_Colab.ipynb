# %% [markdown]
# # Anime Recap Aligner - Google Colab
# Sổ tay này giúp bạn chạy trực tiếp công cụ bằng GPU trên Google Colab siêu nhanh.

# %%
# 1. Tải source code từ Github của bạn về Colab
# !git clone https://github.com/thithi02022004/Recap-Anime.git
# %cd Recap-Anime

# 2. Cài đặt module AI cho backend Python
# !pip install -r requirements.txt

# 3. Cài đặt Node.js modules cho Web UI
# !npm install

# %% [markdown]
# ## Cách 1: Mở Giao diện Web (Web UI)
# Bạn dùng localtunnel để đẩy màn hình giao diện Web đang chạy ẩn trên Google Colab ra một link Public để gắn trên trình duyệt của máy tính.

# %%
import urllib.request

# Lệnh "npm run dev:all &" sẽ chạy cả vite web frontend và proxy server ở chế độ ẩn
get_ipython().system_raw('npm run dev:all &')

print("=========================================")
print("👉 BƯỚC 1: COPY MÃ IP BÊN DƯỚI DÒNG NÀY (VD: 34.123...):")
# !curl ipv4.icanhazip.com
print("👉 BƯỚC 2: CLICK VÀO ĐƯỜNG LINK HTTPS BÊN DƯỚI (MÀ LOCALTUNNEL TẠO RA) VÀ DÁN MÃ IP VÀO TRANG ĐÓ ĐỂ MỞ WEB")
print("=========================================")

# Lấy port 3000 expose lên internet bằng localtunnel
# !npx localtunnel --port 3000

# %% [markdown]
# ## Cách 2: Chạy trực tiếp bằng dòng lệnh (Nhanh hơn, không xài Web UI)
# Bạn tự Upload 2 video của bạn lên thư mục `/content/` bên bảng Menu File trái màn hình. Sau đó sửa tên file trong lệnh bên dưới chạy cho nhanh.

# %%
# Dùng trực tiếp align.py (đã thiết kế chạy trực tiếp rất tốt)
# !python align.py --device cuda --edited "/content/video_edited.mp4" --raw "/content/video_raw.mp4" --output "/content/video_Output_ThanhQuang.mp4"
